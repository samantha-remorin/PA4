# %% [markdown]
# # Programming Assignment #4
# ### DATA WRANGLING AND DATA VISUALIZATION
# #### Submitted by: Samantha Remorin

# %% [markdown]
# **ECE BOARD EXAM PROBLEM:** Using data wrangling and data visualization technique with
# storytelling, analyze the data and present different (i) data frames; and (ii) visuals using the dataset

# %%
#To access pandas library
import pandas as pd

# %%
#load excel dataset
df = pd.read_excel("board2.xlsx")  
df
# Out:
#    Name  Gender             Track  Hometown  Math  Electronics  GEAS  \
# 0    S1    Male   Instrumentation     Luzon    58           89    75
# 1    S2  Female     Communication  Mindanao    52           75    90
# 2    S3  Female   Instrumentation  Mindanao    83           74    77
# 3    S4    Male   Instrumentation   Visayas    65           58    91
# 4    S5    Male     Communication     Luzon    59           86    43
# 5    S6  Female  Microelectronics   Visayas    88           45    86
# 6    S7  Female   Instrumentation     Luzon    66           60    60
# 7    S8    Male   Instrumentation     Luzon    49           81    64
# 8    S9    Male   Instrumentation     Luzon    50           36    63
# 9   S10    Male  Microelectronics  Mindanao    80           84    61
# 10  S11  Female     Communication   Visayas    48           56    48
# 11  S12    Male     Communication   Visayas    89           67    84
# 12  S13  Female  Microelectronics     Luzon    88           35    83
# 13  S14  Female  Microelectronics     Luzon    83           77    89
# 14  S15  Female  Microelectronics  Mindanao    69           41    40
# 15  S16  Female     Communication     Luzon    71           70    87
# 16  S17  Female  Microelectronics  Mindanao    81           79    77
# 17  S18    Male     Communication   Visayas    81           40    81
# 18  S19    Male  Microelectronics     Luzon    79           63    79
# 19  S20  Female     Communication  Mindanao    59           60    62
# 20  S21  Female  Microelectronics   Visayas    83           51    68
# 21  S22  Female     Communication   Visayas    64           39    89
# 22  S23    Male   Instrumentation     Luzon    84           70    74
# 23  S24  Female  Microelectronics   Visayas    85           45    60
# 24  S25    Male     Communication     Luzon    74           91    94
# 25  S26  Female   Instrumentation   Visayas    71           47    83
# 26  S27    Male  Microelectronics   Visayas    70           47    40
# 27  S28    Male     Communication   Visayas    85           53    80
# 28  S29    Male   Instrumentation  Mindanao    73           48    71
# 29  S30    Male   Instrumentation     Luzon    78           81    57
#
#     Communication
# 0              78
# 1              52
# 2              57
# 3              68
# 4              88
# 5              83
# 6              48
# 7              53
# 8              42
# 9              44
# 10             67
# 11             64
# 12             43
# 13             73
# 14             86
# 15             81
# 16             45
# 17             52
# 18             71
# 19             85
# 20             72
# 21             58
# 22             47
# 23             41
# 24             42
# 25             62
# 26             86
# 27             53
# 28             62
# 29             56

# %% [markdown]
# 1. Creation of following data frames based on the format provided:

# %% [markdown]
# a. Filename: Instru = [“Name”, “GEAS”, “Electronics >70”]; where track is constant as
# Instrumentation and hometown Luzon

# %%
#Create a data frame based on the Format given.
#Data frame is called Instru in which it filters rows 
#where grades in Electronics are greater than 70
#Showcases the Name,GEAS, and Electronics
Instru = df.loc[df['Electronics']>70, ['Name','GEAS','Electronics']]

#add column where it will show track as Instrumentation
Instru['Track'] = 'Instrumentation'

#add column where it will show hometown as Luzon
Instru['Hometown'] = 'Luzon'

#Display the Instru DataFrame
Instru
# Out:
#    Name  GEAS  Electronics            Track Hometown
# 0    S1    75           89  Instrumentation    Luzon
# 1    S2    90           75  Instrumentation    Luzon
# 2    S3    77           74  Instrumentation    Luzon
# 4    S5    43           86  Instrumentation    Luzon
# 7    S8    64           81  Instrumentation    Luzon
# 9   S10    61           84  Instrumentation    Luzon
# 13  S14    89           77  Instrumentation    Luzon
# 16  S17    77           79  Instrumentation    Luzon
# 24  S25    94           91  Instrumentation    Luzon
# 29  S30    57           81  Instrumentation    Luzon

# %% [markdown]
# - b. Filename: Mindy = [ “Name”, “Track”, “Electronics”, “Average >=55”]; where hometown is
# constant as Mindanao and gender Female

# %%
#Average is calculated for the four subjects:
# axis 1 is used to get the average (row-wise)
df['Average'] = df[['Math','Electronics','GEAS','Communication']].mean(axis = 1)

#Create a data frame based on the Format given.
#Data frame is called Mindy in which it filters rows where the average is greater than or equal  to 55
#Showcases the Name,Track, and Electronics columns
Mindy = df.loc[df['Average'] >= 55, ['Name','Track','Electronics']]

#add column where it will set hometown as Mindanao
Mindy['Hometown'] = 'Mindanao'

#add column where it will set gender as Female
Mindy['Gender'] = 'Female'

#Print Mindy DataFrame
Mindy
# Out:
#    Name             Track  Electronics  Hometown  Gender
# 0    S1   Instrumentation           89  Mindanao  Female
# 1    S2     Communication           75  Mindanao  Female
# 2    S3   Instrumentation           74  Mindanao  Female
# 3    S4   Instrumentation           58  Mindanao  Female
# 4    S5     Communication           86  Mindanao  Female
# 5    S6  Microelectronics           45  Mindanao  Female
# 6    S7   Instrumentation           60  Mindanao  Female
# 7    S8   Instrumentation           81  Mindanao  Female
# 9   S10  Microelectronics           84  Mindanao  Female
# 11  S12     Communication           67  Mindanao  Female
# 12  S13  Microelectronics           35  Mindanao  Female
# 13  S14  Microelectronics           77  Mindanao  Female
# 14  S15  Microelectronics           41  Mindanao  Female
# 15  S16     Communication           70  Mindanao  Female
# 16  S17  Microelectronics           79  Mindanao  Female
# 17  S18     Communication           40  Mindanao  Female
# 18  S19  Microelectronics           63  Mindanao  Female
# 19  S20     Communication           60  Mindanao  Female
# 20  S21  Microelectronics           51  Mindanao  Female
# 21  S22     Communication           39  Mindanao  Female
# 22  S23   Instrumentation           70  Mindanao  Female
# 23  S24  Microelectronics           45  Mindanao  Female
# 24  S25     Communication           91  Mindanao  Female
# 25  S26   Instrumentation           47  Mindanao  Female
# 26  S27  Microelectronics           47  Mindanao  Female
# 27  S28     Communication           53  Mindanao  Female
# 28  S29   Instrumentation           48  Mindanao  Female
# 29  S30   Instrumentation           81  Mindanao  Female

# %% [markdown]
# 2. Create a visualization that shows how the different features contributes to average grade. Does chosen track in college, gender, or hometown contributes to a higher average score?

# %%
#Import libraries for data visualization
import matplotlib.pyplot as plt

# %%
#Compute first the average of each row or per student for 4 subjects
df['Average'] = df[['Math','Electronics','GEAS','Communication']].mean(axis=1)

# %%
#Group the average
ave_by_track = df.groupby('Track')['Average'].mean()

# Create a figure and an axes object
fig, ax = plt.subplots()

# Create a bar chart on the Axes
ax.bar(ave_by_track.index, ave_by_track.values)

# Set the title and axis labels
ax.set(title='Average by Track', ylabel='Average', xlabel='Track in College')

# Show the plot
plt.show()

# %% [markdown]
# Based on the graph, the chosen track in college contributes to higher average scores, with the Communication track obtaining the highest average, closely followed by Microelectronics, while Instrumentation recorded the lowest average.

# %%
# Group Average by Gender
ave_by_gender = df.groupby('Gender')['Average'].mean()

# Create a figure and an axes object
fig, ax = plt.subplots()

# Create a bar chart on the Axes
ax.bar(ave_by_gender.index, ave_by_gender.values)

# Set the title and axis labels
ax.set(title='Average by Gender', ylabel='Average', xlabel='Gender')

# Show the plot
plt.show()

# %% [markdown]
# Based on the graph, gender contributes to higher average scores, with male students obtaining slightly higher average than female students.

# %%
# Group Average by Hometown
ave_by_hometown = df.groupby('Hometown')['Average'].mean()

# Create a figure and an axes object
fig, ax = plt.subplots()

# Create a bar chart on the Axes
ax.bar(ave_by_hometown.index, ave_by_hometown.values)

# Set the title and axis labels
ax.set(title='Average by Hometown', ylabel='Average', xlabel='Hometown')

# Show the plot
plt.show()

# %% [markdown]
# Based on the graph, hometown contributes to higher average scores, with Luzon obtaining the highest average, followed by Mindanao, while Visayas recorded the lowest average.
